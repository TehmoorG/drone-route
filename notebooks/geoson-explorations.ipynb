# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/Users/tg1523/Library/CloudStorage/OneDrive-ImperialCollegeLondon/drone-route/')
# Print the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/tg1523/Library/CloudStorage/OneDrive-ImperialCollegeLondon/drone-route

# %%
gdf = gpd.read_file('../Snoocode/Archive/G.Accra.geojson')

# %%
# display the first 5 rows of the dataframe
print(gdf.head())
# Out:
#   COUNTRY         NAME_1 VARNAME_1  TYPE_1  ISO_1  Unique_ID  \
# 0   Ghana  Greater Accra        NA  Region  GH-AA         14
#
#                                             geometry
# 0  MULTIPOLYGON (((-0.22106 5.52982, -0.22130 5.5...

# %%
print(gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COUNTRY    1 non-null      object
#  1   NAME_1     1 non-null      object
#  2   VARNAME_1  1 non-null      object
#  3   TYPE_1     1 non-null      object
#  4   ISO_1      1 non-null      object
#  5   Unique_ID  1 non-null      int64
#  6   geometry   1 non-null      geometry
# dtypes: geometry(1), int64(1), object(5)
# memory usage: 188.0+ bytes
# None

# %%
import matplotlib.pyplot as plt

# Plotting the geometry
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
gdf.plot(ax=ax, color='blue', edgecolor='black')
ax.set_title('Greater Accra Region')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.show()
